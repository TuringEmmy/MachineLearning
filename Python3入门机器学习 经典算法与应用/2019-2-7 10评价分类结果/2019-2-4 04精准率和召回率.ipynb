# %% [markdown]
# 股票有可能做成二分类与问题，升降，如果预测股票生为1，降维0，如果股票要生了的话，购买这些股票，股票这个对召回率考虑就不怎么关心，很多上升的股票，如果拉掉了一些，也即是说本来上升，错误的判断为0，但没有关系，因为漏掉了也不会吧钱投进去

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 本来病情就已经非常恶化，如果没有正确的把她预测出来，这样让病人的病情继续恶化下去，可能造成更加严重的后果

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### F1Score

# %% [markdown]
# 二者都兼顾：F1 Score

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 说明F1 Score是precision和recall的调和平均值

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 整理有
# ![image.png](attachment:image.png)

# %% [markdown]
# 化简之后就是这样的
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 代码实现代码

# %%
import numpy as np

# %%
def f1_score(precision, recall):
    try:
        return 2 * precision * recall /(precision + recall)
    except:
        return 0

# %%
precision = 0.5 
recall = 0.5

# %%
f1_score(precision, recall)
# Out:
# 0.5

# %%
precision = 0.1
recall = 0.9
f1_score(precision, recall)
# Out:
# 0.18000000000000002

# %% [markdown]
# 这样的结果就是如果某一个想拉大自己的数字，那么最终的结果就昂视非常低的

# %%
precision = 0.0
recall = 1
f1_score(precision, recall)
# Out:
# 0.0

# %% [markdown]
# ### 在数据集上的实验

# %%
from sklearn import datasets

# %%
digits = datasets.load_digits()
X = digits.data
y = digits.target.copy()

# %%
y[digits.target==9] = 1
y[digits.target!=9] = 0

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X, y)

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()

# %%
log_reg.fit(X_train, y_train)
log_reg.score(X_test, y_test)
# Out:
# 0.9844444444444445

# %%
y_predict = log_reg.predict(X_test)

# %%
from sklearn.metrics import precision_score,recall_score

# %%
precision_score(y_test, y_predict)
# Out:
# 0.9117647058823529

# %%
recall_score(y_test, y_predict)
# Out:
# 0.8857142857142857

# %%
from sklearn.metrics import f1_score

# %%
f1_score(y_test, y_predict)
# Out:
# 0.8985507246376812

# %% [markdown]
# 可以明显降低了，说明数据是有偏的
