# %% [markdown]
# ### 精准率

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 召回率

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 总结:分子相同，分母不同

# %% [markdown]
# > 进一步进行理解

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 为什么使用精准率和召回率？

# %% [markdown]
# ·![image.png](attachment:image.png)
