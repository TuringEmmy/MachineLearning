# %% [markdown]
# ### 分类准确度的问题

# %% [markdown]
# 一个癌症预测系统，输入体检信息，可以判断是否有癌症

# %% [markdown]
# 预测准确度：99.9%
#
# 如果癌症残生的概率只有0.01%
#
# 我们的系统预测所有的人都是健康的，可达到99.9%的准确率

# %% [markdown]
# 对于极度偏斜（Skewed Data）的数据，只使用分类准确度是远远不够的

# %% [markdown]
# 使用混淆矩阵做进一步的分析

# %% [markdown]
# ### 混淆矩阵Confusion Matrix

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 举例说明

# %% [markdown]
# ![image.png](attachment:image.png)
