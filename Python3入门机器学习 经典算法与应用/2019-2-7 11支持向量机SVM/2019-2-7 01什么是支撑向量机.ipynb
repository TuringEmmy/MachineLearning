# %% [markdown]
# ### 什么是支撑向量机？

# %% [markdown]
#  Support Vector Machione

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 红色点和蓝色点都距这条直线较远

# %% [markdown]
# 数学可以证明SVM找到的决策边界，其泛化能力非常的强

# %% [markdown]
# 这个决策边界的特点是距离两边的点都比较远

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 解决的是线性可分问题Hard Margin SVM

# %% [markdown]
# Soft Margin SVM
