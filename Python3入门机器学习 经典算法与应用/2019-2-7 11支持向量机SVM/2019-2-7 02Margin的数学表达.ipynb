# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# margin = 2d
#
# SVM要最大化d

# %% [markdown]
# 回忆解析几何，点到直线的距离

# %% [markdown]
# （x, y）到Ax+By+C=0的距离

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 拓宽到n维空间
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 做完除法之后
# ![image.png](attachment:image.png)

# %% [markdown]
# 公式进行花键之后为
# ![image.png](attachment:image.png)

# %% [markdown]
# 但是为了统一
# ![image.png](attachment:image.png)

# %% [markdown]
# 所以公式为（前后字母含义不一样）：
# ![image.png](attachment:image.png)

# %% [markdown]
# 使用小技巧;
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 最终的优化问题的数学问题
# ![image.png](attachment:image.png)
