# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 将上面的公式转换成下面的公式
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 也就是求解下面这个，新的函数K进行掺入参数，进而进行求解
# ![image.png](attachment:image.png)

# %% [markdown]
# 进而表示成这样的
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 多项式核函数进行举例

# %% [markdown]
# 为了推导方便，这里以2次进行研究
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 所以回到多项式核函数

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 核函数

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
