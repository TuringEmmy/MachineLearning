# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 存在的问题；
# ![image.png](attachment:image.png)
# 此时的结果
# ![image.png](attachment:image.png)

# %% [markdown]
# 这个可以看出一个蓝点对其影响比较大
# ![image.png](attachment:image.png)
# 而这条直线可能更好一些，就是说有一定的容错率

# %% [markdown]
# 更极端的情况，是无法进行分类的
# ![image.png](attachment:image.png)

# %% [markdown]
# 这个就无法使用了，更不用说泛化能力了

# %% [markdown]
# ### Soft margin SVM

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 可以参加参数来平衡两部分所占用的比例

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# C所放的位置是没有什么重大意义的，和线性回归的表意是一样的
