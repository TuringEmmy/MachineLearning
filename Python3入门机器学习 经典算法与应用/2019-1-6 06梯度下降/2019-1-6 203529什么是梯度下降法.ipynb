# %% [markdown]
# 不是一个机器学习的算法
#
# 是一种基于搜索的最优化方法
#
# 作用:最小化一个损失函数
#
# 梯度上升法:最大化一个效用函数

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 梯度下降法并不是所有函数都有位移的极值点

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 解决方案:
#     多次运行,所及初始化点
#     梯度下降法的初始点也是一个超参数

# %% [markdown]
# ![image.png](attachment:image.png)
