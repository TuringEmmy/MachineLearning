# %% [markdown]
# - 批量梯度想将法（Batch Gradient Descent）
#
# - 随机梯度下降法（Stochastic Gradient Descent）
#
# - 小批量梯下降法（Mini-Batch Gradient Descent）

# %% [markdown]
# 小批量就是将上面的两种结合而来
#
# 跳出局部最优
#
# 更快的匀速速度
# ·
# 机器学习领域喝多算法都要使用随机的特点
#
# 随机搜索，随机森林

# %% [markdown]
# 比如网格搜索，就是将所有的参数的组合的全局搜索，随机森林，阿尔法狗里面的蒙特卡洛书都涉及到了随机

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 梯度下降不是一个机器学习算法
#
# 似一种基于搜素偶的最优化方法
#
# 作用：最小化一个损失函数
# 梯度上升法：最大化一个效用函数
