# %% [markdown]
# 对损失函数进行求导

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 先对下面的函数求导
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 对上面地式子再进行化简
# ![image.png](attachment:image.png)

# %% [markdown]
# 顺势函数进行求导前半部分可以有下面的式子
# 第i行j列
# ![image.png](attachment:image.png)

# %% [markdown]
# 上面式子的后半部分
# ![image.png](attachment:image.png)

# %% [markdown]
# 于是可以写成这样
# ![image.png](attachment:image.png)

# %% [markdown]
# 总结后面部分
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 求导的结果

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 最终结果
# ![image.png](attachment:image.png)

# %% [markdown]
# 简化一些可以表达成这样的形式
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 上面的对比是为了发现规律，进行向量化操作
# ![image.png](attachment:image.png)

# %% [markdown]
# 进行向量化操作，就可以进行矩阵运算，可以大大节省运算的时间

# %% [markdown]
# ![image.png](attachment:image.png)
