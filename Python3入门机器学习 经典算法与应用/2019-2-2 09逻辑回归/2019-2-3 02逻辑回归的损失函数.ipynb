# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 损失函数
# ![image.png](attachment:image.png)

# %% [markdown]
# 可以将上面的式子进行合并

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 相应的对于多个样例的时候
# ![image.png](attachment:image.png)

# %% [markdown]
# 其中
# ![image.png](attachment:image.png)
# 即下式：
# ![image.png](attachment:image.png)
# 下面需要做的是找到一组theta，使得下面的这组数据的值最小
# 但是有一个不好的消息是不能像线性回归那样，有一个矩阵来进行计算，不过好消息是很能利用梯度下降法来求解最优解，这个函数是一个凸函数，没有局部最优解 ，所以局部最优解不需要实验多次。
#
# 但是求解上面这个的梯度也好像不是那么容易，但是推导过程就这样
