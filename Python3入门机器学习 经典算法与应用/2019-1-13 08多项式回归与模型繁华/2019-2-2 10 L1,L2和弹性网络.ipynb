# %% [markdown]
# ### 比较Ridge和LASSO
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 衡量正则化--->> 衡量回归好坏--->> 衡量两点之间的距离大小

# %% [markdown]
# ### L1正则， L2正则

# %% [markdown]
# #### 明可夫斯基距离 Minkowski Distance

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 将上面的式子进行泛化
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 写成这样是因为不用开根号，因为结果是一样的
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# n<=2的比较多，但是n是理论是有的

# %% [markdown]
# ### L0正则
# ![image.png](attachment:image.png)

# %% [markdown]
# 实际用L1取代， 因为L0正则的优化是一个NP难的问题，因为每个数需要穷举，通常不使用L0

# %% [markdown]
# ### 弹性网Elastic Net

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 这里是L1和L2，但是有一个r，是两部分所占用的比例，它结合了领回归Ridge回归，其中领回归极易将部分项化成0，造成偏差
