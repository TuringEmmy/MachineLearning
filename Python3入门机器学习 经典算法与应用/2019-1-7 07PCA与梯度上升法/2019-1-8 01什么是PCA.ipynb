# %% [markdown]
# ### 主成分分析principal Component Analysis

# %% [markdown]
# 一个非监督的机器学习算法
#
# 主要用于数据的降维
#
# 通过降维,可以发现更便于人类理解的特征
#
# 其它应用:可视化,去燥

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 如何找到这个样本间间距最大的轴?
#
# 使用方差(Variance)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 第一步:将样本的均值归零demean

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 总结:
#
# 对所有的样本尽心demean处理
#
# 使得所有的样本,映射到w以后,有:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 由于X向量的均值为0,所以又可以化简为下面的这种情况

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# w是单位向量,所以乘以w,求最大值,也就是求原来的最大值

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 接下来对上面的式子进行分析,所要的目标是:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 主成分分析法就化简成了这样
# ![image.png](attachment:image.png)

# %% [markdown]
# 反思特征,
# 要辨别线性回归和主成分分析法的两个梯度方法有什么异同
#
# 在线性回归当中,横轴是特征,纵轴是输出标记
#
# 在主成分分析法当中,纵横两轴都是特征值,找到一条线投影后,点之间的距离最大
