# %% [markdown]
# ### 推到主成分分析法的公式
# ![image.png](attachment:image.png)

# %% [markdown]
# 解决上面的问题,最终还好是求解这个函数的梯度问题,对于这个问题,未知数是w,所有的x是已知的

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 将上面的式子合并一下,就是下面的这种情况,然后使用向量化,避免shiyongfor循环

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 将上面的简写位线面的这种
# ![image.png](attachment:image.png)

# %% [markdown]
# 梯度上升法矩阵化之后就是这样的最终表达式了
# ![image.png](attachment:image.png)
