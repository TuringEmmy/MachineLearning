# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 怎样训练分类器
# ![image.png](attachment:image.png)

# %% [markdown]
# 构建更加复杂的模型

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# scikit当中没有这样的接口
