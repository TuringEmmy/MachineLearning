# %% [markdown]
# ### 多元线性回归

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
boston = datasets.load_boston()

X = boston.data
y = boston.target

X = X[y < 50.0]
y = y[y < 50.0]

# %%
X.shape
# Out:
# (490, 13)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test, y_train, y_test = train_test_split(X,y)

# %%
from LinearRegress.LinearRegression import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit_normal(X_train,y_train)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([-1.27439866e-01,  3.76113004e-02, -4.25080525e-02,  2.97910965e-01,
#        -1.32780497e+01,  3.86019323e+00, -2.47904519e-02, -1.19739756e+00,
#         2.40627747e-01, -1.25742449e-02, -8.88615485e-01,  8.10036311e-03,
#        -3.53186417e-01])

# %%
reg.intercept_
# Out:
# 32.572438206377065

# %%
reg.score(X_test,y_test)
# Out:
# 0.740551604823958
