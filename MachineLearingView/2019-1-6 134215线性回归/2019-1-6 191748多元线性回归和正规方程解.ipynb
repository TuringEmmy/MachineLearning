# %% [markdown]
# ### 多元线性回归

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 对于多元线性回归

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  ![image.png](attachment:image.png)

# %% [markdown]
# 进行向量化处理

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 最终可以简化为

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 将上面的进行推广

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 那么就是这样的了

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 所以,就成了下面的问题,和前面的简单线性回归一样

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 求解的sita,多元线性回归的正规方程解(Normal Equation)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 问题:时间复杂度高:O(n^3) 优化O(n^2.4)
#
# 优点::不需要对数据做归一化处理
