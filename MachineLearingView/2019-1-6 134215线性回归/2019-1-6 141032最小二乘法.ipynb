# %% [markdown]
# ### 最小二乘法

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 对a进行求导

# %% [markdown]
# `![image.png](attachment:image.png)

# %% [markdown]
# 对上式进行整理
# ![image.png](attachment:image.png)

# %% [markdown]
# 进一步移项
# ![image.png](attachment:image.png)

# %% [markdown]
# 先对部分项进行整理

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 对上面的式子大手术

# %% [markdown]
# ![image.png](attachment:image.png)
