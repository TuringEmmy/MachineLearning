# %% [markdown]
# ### 梯度下降法

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 梯度代表方向,对应J增大最快的方法

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 圈线代表等高线

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 但是这个m是无关的

# %% [markdown]
# ![image.png](attachment:image.png)
